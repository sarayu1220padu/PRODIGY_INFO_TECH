# %% [markdown]
# ## **TASK - 1**

# %% [markdown]
# # 🌍 World Population Analysis

# %% [markdown]
# ## 📦 Importing Libraries

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
import numpy as np

# %% [markdown]
# ## 📂 Loading Dataset

# %%
# Upload your dataset file in Google Colab before running this line
df = pd.read_csv('world_population_worldbank.csv')

# %%
# Display the first few rows
df.head()
# Out:
#                   Country Name Country Code         1960         1961  \
# 0                        Aruba          ABW      54608.0      55811.0
# 1  Africa Eastern and Southern          AFE  130692579.0  134169237.0
# 2                  Afghanistan          AFG    8622466.0    8790140.0
# 3   Africa Western and Central          AFW   97256290.0   99314028.0
# 4                       Angola          AGO    5357195.0    5441333.0
#
#           1962         1963         1964         1965         1966  \
# 0      56682.0      57475.0      58178.0      58782.0      59291.0
# 1  137835590.0  141630546.0  145605995.0  149742351.0  153955516.0
# 2    8969047.0    9157465.0    9355514.0    9565147.0    9783147.0
# 3  101445032.0  103667517.0  105959979.0  108336203.0  110798486.0
# 4    5521400.0    5599827.0    5673199.0    5736582.0    5787044.0
#
#           1967  ...         2014         2015         2016         2017  \
# ...

# %%
# Display the last few rows
df.tail()
# Out:
#      Country Name Country Code        1960        1961        1962  \
# 261        Kosovo          XKX    990150.0   1014211.0   1038618.0
# 262   Yemen, Rep.          YEM   5542459.0   5646668.0   5753386.0
# 263  South Africa          ZAF  16520441.0  16989464.0  17503133.0
# 264        Zambia          ZMB   3119430.0   3219451.0   3323427.0
# 265      Zimbabwe          ZWE   3806310.0   3925952.0   4049778.0
#
#            1963        1964        1965        1966        1967  ...  \
# 261   1063175.0   1087700.0   1111812.0   1135522.0   1159611.0  ...
# 262   5860197.0   5973803.0   6097298.0   6228430.0   6368014.0  ...
# 263  18042215.0  18603097.0  19187194.0  19789771.0  20410677.0  ...
# 264   3431381.0   3542764.0   3658024.0   3777680.0   3901288.0  ...
# 265   4177931.0   4310332.0   4447149.0   4588529.0   4734694.0  ...
#
#            2014        2015        2016        2017        2018        2019  \
# ...

# %% [markdown]
# ## 🔍 Viewing Dataset Information

# %%
# View Dataset Info
print("🔎 Dataset Information:\n")
df.info()
# Out:
# 🔎 Dataset Information:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 66 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Name  266 non-null    object
#  1   Country Code  266 non-null    object
#  2   1960          264 non-null    float64
#  3   1961          264 non-null    float64
#  4   1962          264 non-null    float64
#  5   1963          264 non-null    float64
#  6   1964          264 non-null    float64
#  7   1965          264 non-null    float64
#  8   1966          264 non-null    float64
#  9   1967          264 non-null    float64
#  10  1968          264 non-null    float64
#  11  1969          264 non-null    float64
#  12  1970          264 non-null    float64
#  13  1971          264 non-null    float64
#  14  1972          264 non-null    float64
#  15  1973          264 non-null    float64
#  16  1974          264 non-null    float64
# ...

# %%
#Summary Statistics
print("\n📊 Dataset Description:\n")
print(df.describe())
# Out:
# 📊 Dataset Description:
#
#                1960          1961          1962          1963          1964  \
# count  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02
# mean   1.157939e+08  1.173869e+08  1.195401e+08  1.222050e+08  1.248922e+08
# std    3.639920e+08  3.684672e+08  3.751049e+08  3.837174e+08  3.923714e+08
# min    2.646000e+03  2.888000e+03  3.171000e+03  3.481000e+03  3.811000e+03
# 25%    5.132212e+05  5.231345e+05  5.337595e+05  5.449288e+05  5.566630e+05
# 50%    3.708088e+06  3.816540e+06  3.931214e+06  4.033994e+06  4.112910e+06
# 75%    2.670606e+07  2.748694e+07  2.830289e+07  2.914708e+07  3.001684e+07
# max    3.031517e+09  3.072470e+09  3.126894e+09  3.193470e+09  3.260480e+09
#
#                1965          1966          1967          1968          1969  \
# count  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02
# mean   1.276182e+08  1.304676e+08  1.333152e+08  1.362430e+08  1.392759e+08
# ...

# %% [markdown]
# ## 🧹 Data Cleaning

# %%
# Check for missing values
print("Missing values per column:")
print(df.isnull().sum())
# Out:
# Missing values per column:
# Country Name    0
# Country Code    0
# 1960            2
# 1961            2
# 1962            2
#                ..
# 2019            1
# 2020            1
# 2021            1
# 2022            1
# 2023            1
# Length: 66, dtype: int64

# %%
print(df.columns)
# Out:
# Index(['Country Name', 'Country Code', '1960', '1961', '1962', '1963', '1964',
#        '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973',
#        '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982',
#        '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991',
#        '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000',
#        '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009',
#        '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018',
#        '2019', '2020', '2021', '2022', '2023'],
#       dtype='object')

# %% [markdown]
# ## 📈 Extracting Population of 2021

# %%
#Plotting the top 10 countries by population in 2021
df_2021 = df[['Country Name', '2021']]
df_2021 = df_2021.dropna()
df_2021.columns = ['Country', 'Population']

# %%
print("✅ Extracted 2021 Population Data (first 10 rows):")
display(df_2021.head(10))  # Display first 10 rows of cleaned data
# Out:
# ✅ Extracted 2021 Population Data (first 10 rows):
#                        Country   Population
# 0                        Aruba     106537.0
# 1  Africa Eastern and Southern  702977106.0
# 2                  Afghanistan   40099462.0
# 3   Africa Western and Central  478185907.0
# 4                       Angola   34503774.0
# 5                      Albania    2811666.0
# 6                      Andorra      79034.0
# 7                   Arab World  456520777.0
# 8         United Arab Emirates    9365145.0
# 9                    Argentina   45808747.0

# %% [markdown]
# ## 🌟 Top 10 Countries by Population in 2021

# %%
# Get Top 10 Most Populated Countries in 2021
top10 = df_2021.sort_values('Population', ascending=False).head(10)

# %%
print("\n🌍 Top 10 Countries by Population in 2021:")
display(top10)
# Out:
# 🌍 Top 10 Countries by Population in 2021:
#                         Country    Population
# 259                       World  7.888964e+09
# 103            IDA & IBRD total  6.696374e+09
# 140         Low & middle income  6.467799e+09
# 156               Middle income  5.782549e+09
# 102                   IBRD only  4.894666e+09
# 62   Early-demographic dividend  3.411268e+09
# 139         Lower middle income  2.983113e+09
# 249         Upper middle income  2.799436e+09
# 63          East Asia & Pacific  2.370214e+09
# 142   Late-demographic dividend  2.323185e+09

# %% [markdown]
# ## 📊 Data Visualization - Bar Chart

# %%
#  Plot bar chart for top 10 countries
sns.set(style="whitegrid")
plt.figure(figsize=(12, 6))
sns.barplot(data=top10, x="Country", y="Population", palette="viridis")
# Add titles and labels
plt.title("Top 10 Countries by Population in 2021", fontsize=16)
plt.xlabel("Country", fontsize=12)
plt.ylabel("Population", fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()
# Show the plot
plt.show()
# Out:
# <ipython-input-16-bea9f598cb31>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top10, x="Country", y="Population", palette="viridis")

# %% [markdown]
# ## 📊 Data Visualization - Histogram

# %%
# Drop missing population data for 2021 (if any)
df_2021 = df.dropna(subset=['2021'])

plt.figure(figsize=(12, 6))
sns.histplot(df_2021['2021'], bins=30, kde=True, color='skyblue')

plt.title("Distribution of Country Populations in 2021", fontsize=16)
plt.xlabel("Population", fontsize=12)
plt.ylabel("Number of Countries", fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# # ✅ Conclusion
# In this analysis, we explored the World Bank population dataset and focused on extracting population data for the year 2021. After cleaning and preprocessing the dataset:
#
# - We displayed summary statistics and structural information using `.info()` and `.describe()`.
# - We extracted and sorted population data for all countries in 2021.
# - We visualized the **Top 10 most populated countries in 2021** using a bar chart.
# - We also created a **histogram** to visualize the overall distribution of population values across all countries.
#
# This analysis highlights population concentration patterns and provides useful insights into global demographics. The steps followed demonstrate essential skills in **data cleaning, transformation, and visualization using Python**, making this a strong foundational task for internship-level data analysis.
